# %%
pip install opendatasets

# %%
import numpy as np
import pandas as pd

# %%
import opendatasets as od

# Specify the Kaggle dataset URL
dataset_url = 'https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata'

# Define the files you want to download
files_to_download = ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']

# Download the specified files from the dataset
od.download(dataset_url, files=files_to_download)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: adityagaikwad9552
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 8.89M/8.89M [00:00<00:00, 68.6MB/s]

# %%
credits = pd.read_csv('/content/tmdb-movie-metadata/tmdb_5000_credits.csv')

# %%
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
credits = credits.rename(columns={'movie_id':'id'})

# %%
credits = credits[['cast','crew', 'id']]
credits
# Out:
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew      id
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...   19995
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...     285
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...  206647
# ...

# %%
meta = pd.read_csv('/content/tmdb-movie-metadata/tmdb_5000_movies.csv')

# %%
pd.set_option('display.max_columns', None)
meta
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
meta.shape
# Out:
# (4803, 20)

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
# creating year column by extracting only year from release_date column
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# year
# 1916.0      1
# 1925.0      1
# 1927.0      1
# 1929.0      2
# 1930.0      1
#          ...
# 2013.0    231
# 2014.0    238
# 2015.0    216
# 2016.0    104
# 2017.0      1
# Name: count, Length: 90, dtype: int64

# %%
meta.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'year'],
#       dtype='object')

# %%
new_meta = meta[['genres', 'id', 'title','year','revenue']]

# %%
new_meta
# Out:
#                                                  genres      id  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...                                                 ...     ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801                                                 []  126186
# 4802                [{"id": 99, "name": "Documentary"}]   25975
#
#                                          title    year     revenue
# 0                                       Avatar  2009.0  2787965087
# ...

# %%
new_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   genres   4803 non-null   object
#  1   id       4803 non-null   int64
#  2   title    4803 non-null   object
#  3   year     4802 non-null   float64
#  4   revenue  4803 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 187.7+ KB

# %%
new_meta['id'] = new_meta['id'].astype(int)
# Out:
# <ipython-input-18-1f0b0c8534b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta, credits, on='id')

# %%
print(data['genres'].dtypes)
print(data['cast'].dtypes)
print(data['crew'].dtypes)
# Out:
# object
# object
# object

# %%
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
data['year'].value_counts().sort_index()
# Out:
# year
# 1916.0      1
# 1925.0      1
# 1927.0      1
# 1929.0      2
# 1930.0      1
#          ...
# 2013.0    231
# 2014.0    238
# 2015.0    216
# 2016.0    104
# 2017.0      1
# Name: count, Length: 90, dtype: int64

# %%
# here we convert name(key) from genre column into scifi(value),
# if name(key) = science fiction(value)

def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0       Action Adventure Fantasy Sci-Fi
# 1              Adventure Fantasy Action
# 2                Action Adventure Crime
# 3           Action Crime Drama Thriller
# 4               Action Adventure Sci-Fi
#                      ...
# 4798              Action Crime Thriller
# 4799                     Comedy Romance
# 4800      Comedy Drama Romance TV Movie
# 4801                                NaN
# 4802                        Documentary
# Name: genres_list, Length: 4803, dtype: object

# %%
# getting the first actor name from all movies

def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# get() method is used to get values of specified key from dict

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
data['actor_1_name']
# Out:
# 0       Sam Worthington
# 1           Johnny Depp
# 2          Daniel Craig
# 3        Christian Bale
# 4         Taylor Kitsch
#              ...
# 4798    Carlos Gallardo
# 4799       Edward Burns
# 4800        Eric Mabius
# 4801      Daniel Henney
# 4802     Drew Barrymore
# Name: actor_1_name, Length: 4803, dtype: object

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0            Zoe Saldana
# 1          Orlando Bloom
# 2        Christoph Waltz
# 3          Michael Caine
# 4           Lynn Collins
#               ...
# 4798      Jaime de Hoyos
# 4799         Kerry Bishé
# 4800       Kristin Booth
# 4801         Eliza Coupe
# 4802    Brian Herzlinger
# Name: actor_2_name, Length: 4803, dtype: object

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0       Sigourney Weaver
# 1        Keira Knightley
# 2            Léa Seydoux
# 3            Gary Oldman
# 4        Samantha Morton
#               ...
# 4798     Peter Marquardt
# 4799     Marsha Dietlein
# 4800        Crystal Lowe
# 4801         Bill Paxton
# 4802       Corey Feldman
# Name: actor_3_name, Length: 4803, dtype: object

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0                              James Cameron
# 1                             Gore Verbinski
# 2                                 Sam Mendes
# 3                          Christopher Nolan
# 4                             Andrew Stanton
#                         ...
# 4798                        Robert Rodriguez
# 4799                            Edward Burns
# 4800                             Scott Smith
# 4801                             Daniel Hsia
# 4802    Brian Herzlinger Jon Gunn Brett Winn
# Name: director_name, Length: 4803, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title','id','year','revenue']]

# %%
movie
# Out:
#                              director_name     actor_1_name      actor_2_name  \
# 0                            James Cameron  Sam Worthington       Zoe Saldana
# 1                           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2                               Sam Mendes     Daniel Craig   Christoph Waltz
# 3                        Christopher Nolan   Christian Bale     Michael Caine
# 4                           Andrew Stanton    Taylor Kitsch      Lynn Collins
# ...                                    ...              ...               ...
# 4798                      Robert Rodriguez  Carlos Gallardo    Jaime de Hoyos
# 4799                          Edward Burns     Edward Burns       Kerry Bishé
# 4800                           Scott Smith      Eric Mabius     Kristin Booth
# 4801                           Daniel Hsia    Daniel Henney       Eliza Coupe
# 4802  Brian Herzlinger Jon Gunn Brett Winn   Drew Barrymore  Brian Herzlinger
#
# ...

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})
movie = movie.rename(columns={'id':'movie_id'})

# %%
movie.isna().sum()
# Out:
# director_name    30
# actor_1_name     43
# actor_2_name     53
# actor_3_name     63
# genres           28
# movie_title       0
# movie_id          0
# year              1
# revenue           0
# dtype: int64

# %%
movie = movie.dropna(subset=movie.columns.difference(['year']), how='any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# movie_id         0
# year             0
# revenue          0
# dtype: int64

# %%
movie.shape
# Out:
# (4721, 9)

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#                              director_name     actor_1_name      actor_2_name  \
# 0                            James Cameron  Sam Worthington       Zoe Saldana
# 1                           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2                               Sam Mendes     Daniel Craig   Christoph Waltz
# 3                        Christopher Nolan   Christian Bale     Michael Caine
# 4                           Andrew Stanton    Taylor Kitsch      Lynn Collins
# ...                                    ...              ...               ...
# 4796                         Shane Carruth    Shane Carruth    David Sullivan
# 4798                      Robert Rodriguez  Carlos Gallardo    Jaime de Hoyos
# 4799                          Edward Burns     Edward Burns       Kerry Bishé
# 4800                           Scott Smith      Eric Mabius     Kristin Booth
# 4802  Brian Herzlinger Jon Gunn Brett Winn   Drew Barrymore  Brian Herzlinger
#
# ...

# %%
movie.to_csv('movies_2.csv',index=False)
